# %% [markdown]
# <a href="https://colab.research.google.com/github/rogeriodelphi/trader_esportivo_analises/blob/main/FutPythonTrader_An%C3%A1lises_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando as Bibliotecas
import pandas as pd
import numpy as np
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
# # Importando a Base de Dados
# df = pd.read_excel('Base_de_Dados_Full_v2.xlsx')
df = pd.read_excel('/x_FutPythonTrader_Base_de_Dados_Temporadas_Passadas_x.xlsx')

# %%
# Renomeando as Colunas e Ordenando por Data os Jogos
df = df[['League','Date','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Goals_H','FT_Goals_A']]
df.columns = ['League','Date','Home','Away','Odds_H','Odds_D','Odds_A','Goals_H','Goals_A']
df.loc[(df['Goals_H']  > df['Goals_A']), "Result"] = "H"
df.loc[(df['Goals_H'] == df['Goals_A']), "Result"] = "D"
df.loc[(df['Goals_H'] <  df['Goals_A']), "Result"] = "A"

df['Date'] = df['Date'].dt.strftime('%Y/%m/%d')
df = df.sort_values('Date')
df.head()
# Out:
#     League        Date         Home       Away  Odds_H  Odds_D  Odds_A  \
# 0  Noruega  2012/01/04  Fredrikstad    Stabaek    2.00    3.81    3.88
# 1  Noruega  2012/01/04    Haugesund      Molde    2.35    3.64    3.13
# 2  Noruega  2012/01/04      Sogndal   Honefoss    2.04    3.38    4.20
# 3  Noruega  2012/01/04       Viking        Odd    1.79    3.88    4.84
# 4  Noruega  2012/01/04   Lillestrom  Rosenborg    3.30    3.48    2.33
#
#    Goals_H  Goals_A Result
# 0        5        1      H
# 1        2        0      H
# 2        0        0      D
# 3        1        0      H
# 4        2        2      D

# %%
# Ajustando o Índice
df.reset_index(inplace=True, drop=True)
df.index = df.index.set_names(['Nº do Jogo'])
df = df.rename(index=lambda x: x + 1)

# %%
# Visualizando o DataFrame
df.head(10)
# Out:
#              League        Date                Home                    Away  \
# Nº do Jogo
# 1           Noruega  2012/01/04         Fredrikstad                 Stabaek
# 2           Noruega  2012/01/04           Haugesund                   Molde
# 3           Noruega  2012/01/04             Sogndal                Honefoss
# 4           Noruega  2012/01/04              Viking                     Odd
# 5           Noruega  2012/01/04          Lillestrom               Rosenborg
# 6            Suécia  2012/01/04                 AIK                 Mjallby
# 7            Suécia  2012/01/04           Syrianska                Goteborg
# 8               USA  2012/01/04    Portland Timbers          Real Salt Lake
# 9               USA  2012/01/04    Seattle Sounders    San Jose Earthquakes
# 10              USA  2012/01/04  Los Angeles Galaxy  New England Revolution
#
#             Odds_H  Odds_D  Odds_A  Goals_H  Goals_A Result
# Nº do Jogo
# ...

# %%
# Criando a Coluna de Pontos Obtidos
def Pontos_H (Result):
    if Result == 'H':
        Pontos = 3
    elif Result == 'D':
        Pontos = 1
    else:
        Pontos = 0
    return Pontos

def Pontos_A (Result):
    if Result == 'A':
        Pontos = 3
    elif Result == 'D':
        Pontos = 1
    else:
        Pontos = 0
    return Pontos

df['Pontos_H'] = df.apply(lambda row: Pontos_H(row['Result']), axis=1)
df['Pontos_A'] = df.apply(lambda row: Pontos_A(row['Result']), axis=1)

# %%
# Visualizando o DataFrame
df.head(10)
# Out:
#              League        Date                Home                    Away  \
# Nº do Jogo
# 1           Noruega  2012/01/04         Fredrikstad                 Stabaek
# 2           Noruega  2012/01/04           Haugesund                   Molde
# 3           Noruega  2012/01/04             Sogndal                Honefoss
# 4           Noruega  2012/01/04              Viking                     Odd
# 5           Noruega  2012/01/04          Lillestrom               Rosenborg
# 6            Suécia  2012/01/04                 AIK                 Mjallby
# 7            Suécia  2012/01/04           Syrianska                Goteborg
# 8               USA  2012/01/04    Portland Timbers          Real Salt Lake
# 9               USA  2012/01/04    Seattle Sounders    San Jose Earthquakes
# 10              USA  2012/01/04  Los Angeles Galaxy  New England Revolution
#
#             Odds_H  Odds_D  Odds_A  Goals_H  Goals_A Result  Pontos_H  \
# Nº do Jogo
# ...

# %%
# Criando uma coluna de Total de Gols
df['Total_Goals'] = df.apply(lambda row: (row['Goals_H'] + row['Goals_A']), axis=1)

# %%
# Criando as colunas para +0.5, +1.5, +2.5 e Ambas marcam
df['Over05'] = df.apply(lambda row: 1 if (row['Total_Goals'] >= 1) else 0, axis=1)
df['Over15'] = df.apply(lambda row: 1 if (row['Total_Goals'] > 1) else 0, axis=1)
df['Over25'] = df.apply(lambda row: 1 if (row['Total_Goals'] > 2) else 0, axis=1)
df['BTTS'] = df.apply(lambda row: 1 if (row['Goals_H'] > 0 and row['Goals_A'] > 0) else 0, axis=1)
df['Not_BTTS'] = df.apply(lambda row: 1 if (row['Goals_H'] == 0 or row['Goals_A'] == 0) else 0, axis=1)

# %%
df.head()
# Out:
#              League        Date         Home       Away  Odds_H  Odds_D  \
# Nº do Jogo
# 1           Noruega  2012/01/04  Fredrikstad    Stabaek    2.00    3.81
# 2           Noruega  2012/01/04    Haugesund      Molde    2.35    3.64
# 3           Noruega  2012/01/04      Sogndal   Honefoss    2.04    3.38
# 4           Noruega  2012/01/04       Viking        Odd    1.79    3.88
# 5           Noruega  2012/01/04   Lillestrom  Rosenborg    3.30    3.48
#
#             Odds_A  Goals_H  Goals_A Result  Pontos_H  Pontos_A  Total_Goals  \
# Nº do Jogo
# 1             3.88        5        1      H         3         0            6
# 2             3.13        2        0      H         3         0            2
# 3             4.20        0        0      D         1         1            0
# 4             4.84        1        0      H         3         0            1
# 5             2.33        2        2      D         1         1            4
#
# ...

# %%
# Criando as varíáveis para calcular +0.5, +1.5, +2.5 e Ambas marcam para Home e Away
media_over05_H = round(df[['Home', 'Over05']].groupby('Home').mean() * 100, 2)
media_over15_H = round(df[['Home', 'Over15']].groupby('Home').mean() * 100, 2)
media_over25_H = round(df[['Home', 'Over25']].groupby('Home').mean() * 100, 2)
media_BTTS_H = round(df[['Home', 'BTTS']].groupby('Home').mean() * 100, 2)
media_Not_BTTS_H = round(df[['Home', 'Not_BTTS']].groupby('Home').mean() * 100, 2)

media_over05_A = round(df[['Away', 'Over05']].groupby('Away').mean() * 100, 2)
media_over15_A = round(df[['Away', 'Over15']].groupby('Away').mean() * 100, 2)
media_over25_A = round(df[['Away', 'Over25']].groupby('Away').mean() * 100, 2)
media_Not_BTTS_A = round(df[['Away', 'Not_BTTS']].groupby('Away').mean() * 100, 2)

# %%
# Criar o df_medias_H e df_medias_A e concatenar as variáveis de médias
df_medias_H = pd.concat([media_over05_H, media_over15_H, media_over25_H, media_BTTS_H, media_Not_BTTS_H], axis=1)
df_medias_A = pd.concat([media_over05_A, media_over15_A, media_over25_A, media_BTTS_A, media_Not_BTTS_A], axis=1)

# %%
# Renomeando os nomes das colunas
df_medias_H.columns = ['Média_Over05_H','Média_Over15_H','Média_Over25_H','Média_BTTS_H', 'Média_Not_BTTS_H']
df_medias_H.to_excel("medias_H.xlsx")

df_medias_A.columns = ['Média_Over05_A','Média_Over15_A','Média_Over25_A','Média_BTTS_A', 'Média_Not_BTTS_A']
df_medias_A.to_excel("medias_A.xlsx")

# %%
# Visualizando o DataFrame df_medias_H
df_medias_H.head(10)
# Out:
#                 Média_Over05_H  Média_Over15_H  Média_Over25_H  Média_BTTS_H  \
# Home
# A. Klagenfurt            96.00           84.00           60.00         64.00
# A. Lustenau              87.50           87.50           75.00         62.50
# AC Oulu                  93.10           79.31           41.38         44.83
# AEK                      92.19           74.22           51.56         39.84
# AFC Eskilstuna           83.87           67.74           48.39         61.29
# AIK                      92.73           69.09           41.82         45.45
# AZ Alkmaar               95.15           83.64           65.45         54.55
# Aalborg                  93.26           73.03           43.82         48.31
# Aalen                    90.20           70.59           47.06         41.18
# Aalesund                 95.04           80.99           59.50         63.64
#
#                 Média_Not_BTTS_H
# Home
# A. Klagenfurt              36.00
# A. Lustenau                37.50
# ...

# %%
# Visualizando o DataFrame df_medias_A
df_medias_A.head(10)
# Out:
#                 Média_Over05_A  Média_Over15_A  Média_Over25_A  Média_BTTS_A  \
# Away
# A. Klagenfurt           100.00           88.00           64.00         68.00
# A. Lustenau             100.00           87.50           50.00         75.00
# AC Oulu                  89.66           72.41           62.07         58.62
# AEK                      88.00           64.00           36.80         40.00
# AFC Eskilstuna           93.55           74.19           61.29         48.39
# AIK                      90.85           71.95           50.00         53.05
# AZ Alkmaar               97.58           89.70           67.88         63.03
# Aalborg                  91.48           76.70           53.98         53.98
# Aalen                    84.31           64.71           35.29         43.14
# Aalesund                 95.00           80.83           63.33         59.17
#
#                 Média_Not_BTTS_A
# Away
# A. Klagenfurt              32.00
# A. Lustenau                25.00
# ...

# %%
# Analisando dois times específicos
home = input("Digite o nome do Mandante: ")
away = input("Digite o nome do Visitante: ")

flt1 = df_medias_H[df_medias_H.index == home];
flt2 = df_medias_A[df_medias_A.index == away];

display(flt1, flt2)
# Out:
# Digite o nome do Mandante: Chelsea
# Digite o nome do Visitante: Arsenal
#          Média_Over05_H  Média_Over15_H  Média_Over25_H  Média_BTTS_H  \
# Home
# Chelsea           93.68           80.53           53.68         48.95
#
#          Média_Not_BTTS_H
# Home
# Chelsea             51.05
#          Média_Over05_A  Média_Over15_A  Média_Over25_A  Média_BTTS_A  \
# Away
# Arsenal           94.21           76.84           56.84         54.21
#
#          Média_Not_BTTS_A
# Away
# Arsenal             45.79
