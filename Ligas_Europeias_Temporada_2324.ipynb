# %% [markdown]
# <a href="https://colab.research.google.com/github/rogeriodelphi/trader_esportivo_analises/blob/main/Ligas_Europeias_Temporada_2324.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ligas Europeias - Temporada 2324

# %%
# Importando as Bibliotecas
import pandas as pd
import warnings

# Removendo as mensagens de warning
import warnings
warnings.filterwarnings('ignore')

# Formatando o DataFrame
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %% [markdown]
# ## Coletando as planilhas das Ligas Principais

# %%
# Inglaterra 1
ENG1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/E0.csv")
ENG1['Liga'] = 'Inglaterra 1'

# Inglaterra 2
ENG2 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/E1.csv")
ENG2['Liga'] = 'Inglaterra 2'

# Escócia 1
SCO1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/SC0.csv")
SCO1['Liga'] = 'Escócia 1'

# Alemanha 1
GER1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/D1.csv")
GER1['Liga'] = 'Alemanha 1'

# Alemanha 2
GER2 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/D2.csv")
GER2['Liga'] = 'Alemanha 2'

# Itália 1
ITA1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/I1.csv")
ITA1['Liga'] = 'Itália 1'

# Itália 2
ITA2 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/I2.csv")
ITA2['Liga'] = 'Itália 2'

# Espanha 1
SPA1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/SP1.csv")
SPA1['Liga'] = 'Espanha 1'

# Espanha 2
SPA2 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/SP2.csv")
SPA2['Liga'] = 'Espanha 2'

# França 1
FRA1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/F1.csv")
FRA1['Liga'] = 'França 1'

# França 2
FRA2 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/F2.csv")
FRA2['Liga'] = 'França 2'

# Holanda 1
NET1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/N1.csv")
NET1['Liga'] = 'Holanda 1'

# Bélgica 1
BEL1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/B1.csv")
BEL1['Liga'] = 'Bélgica 1'

# Portugal 1
POR1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/P1.csv")
POR1['Liga'] = 'Portugal 1'

# Turquia 1
TUR1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/T1.csv")
TUR1['Liga'] = 'Turquia 1'

# Grécia 1
GRE1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/G1.csv")
GRE1['Liga'] = 'Grécia 1'

# %% [markdown]
# ## Concatenando as Planilhas

# %%
df = [ENG1, ENG2, SCO1, GER1, GER2, ITA1, ITA2, SPA1, SPA2, FRA1, FRA2, NET1, BEL1, POR1, TUR1, GRE1]
df = pd.concat(df)
df.head().T
# Out:
#                      0              1             2             3  \
# Div                 E0             E0            E0            E0
# Date        11/08/2023     12/08/2023    12/08/2023    12/08/2023
# Time             20:00          12:30         15:00         15:00
# HomeTeam       Burnley        Arsenal   Bournemouth      Brighton
# AwayTeam      Man City  Nott'm Forest      West Ham         Luton
# ...                ...            ...           ...           ...
# MaxCAHH            NaN           2.01          2.06          2.14
# MaxCAHA            NaN           2.09          1.96          1.93
# AvgCAHH           1.92           1.95          1.96           2.0
# AvgCAHA           1.95           1.92          1.91          1.86
# Liga      Inglaterra 1   Inglaterra 1  Inglaterra 1  Inglaterra 1
#
#                      4
# Div                 E0
# Date        12/08/2023
# Time             15:00
# HomeTeam       Everton
# AwayTeam        Fulham
# ...                ...
# ...

# %% [markdown]
# ## Selecionando e Renomeando as colunas que serão utilizadas

# %%
df = df[['Liga','Date','HomeTeam','AwayTeam','HTHG','HTAG','HTR','FTHG','FTAG','FTR','B365H','B365D','B365A', 'HST', 'AST', 'HC', 'AC']]
df.columns = ['League','Date','Home','Away','Goals_H_HT','Goals_A_HT','Result_HT','Goals_H_FT','Goals_A_FT','Result_FT','Odd_H','Odds_D','Odds_A', 'Shots_H', 'Shots_A', 'Corners_H', 'Corners_A']

# %%
# Visualizando o Resultado Final
df.shape
# Out:
# (2743, 17)

# %% [markdown]
# ## Informações do DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2743 entries, 0 to 103
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   League      2743 non-null   object
#  1   Date        2743 non-null   object
#  2   Home        2743 non-null   object
#  3   Away        2743 non-null   object
#  4   Goals_H_HT  2743 non-null   int64
#  5   Goals_A_HT  2743 non-null   int64
#  6   Result_HT   2743 non-null   object
#  7   Goals_H_FT  2743 non-null   int64
#  8   Goals_A_FT  2743 non-null   int64
#  9   Result_FT   2743 non-null   object
#  10  Odd_H       2739 non-null   float64
#  11  Odds_D      2739 non-null   float64
#  12  Odds_A      2739 non-null   float64
#  13  Shots_H     2743 non-null   int64
#  14  Shots_A     2743 non-null   int64
#  15  Corners_H   2743 non-null   int64
#  16  Corners_A   2743 non-null   int64
# dtypes: float64(3), int64(8), object(6)
# memory usage: 385.7+ KB

# %% [markdown]
# # Dropando as linhas com NAN

# %%
df = df.dropna()

# %% [markdown]
# ## Visualizando o Resultado Final

# %%
df.info

# %%
# Criando o campo coluna 'Total_Corners'no DataFrame df
df['Total_Corners'] = df.apply(lambda row: (row['Corners_H'] + row['Corners_A']), axis=1)

# %%
df.head()
# Out:
# ...
#          League        Date         Home           Away  Goals_H_HT  \
# 0  Inglaterra 1  11/08/2023      Burnley       Man City           0
# 1  Inglaterra 1  12/08/2023      Arsenal  Nott'm Forest           2
# 2  Inglaterra 1  12/08/2023  Bournemouth       West Ham           0
# 3  Inglaterra 1  12/08/2023     Brighton          Luton           1
# 4  Inglaterra 1  12/08/2023      Everton         Fulham           0
#
#    Goals_A_HT Result_HT  Goals_H_FT  Goals_A_FT Result_FT  ...  Odds_A  \
# 0           2         A           0           3         A  ...    1.33
# 1           0         H           2           1         H  ...   15.00
# 2           0         D           1           1         D  ...    2.55
# 3           0         H           4           1         H  ...    9.00
# 4           0         D           0           1         A  ...    3.30
#
#    Shots_H  Shots_A  Corners_H  Corners_A  Total_Corners  Total_Goals_HT  \
# ...

# %% [markdown]
# ## Exportando arquivo final para o Excel

# %%
df.to_excel("Ligas Europeias - Temporada 2324.xlsx", index=False)

# %% [markdown]
# ## Calculando as porcentagens de Over 0.5 HT, 1.5 HT e 2.5 HT

# %%
# Criando o campo coluna 'Total_Goals_HT'no DataFrame df
df['Total_Goals_HT'] = df.apply(lambda row: (row['Goals_H_HT'] + row['Goals_A_HT']), axis=1)

# Calculando as porcentagens de Over 0.5 HT, 1.5 HT e 2.5 HT
df['Over05_HT'] = df.apply(lambda row: 1 if (row['Total_Goals_HT'] >= 1) else 0, axis=1)
df['Over15_HT'] = df.apply(lambda row: 1 if (row['Total_Goals_HT'] > 1) else 0, axis=1)
df['Over25_HT'] = df.apply(lambda row: 1 if (row['Total_Goals_HT'] > 2) else 0, axis=1)

# Calculando as médias over HT para Home
media_over05_HT_H = round(df[['Home', 'Over05_HT']].groupby('Home').mean() * 100, 2)
media_over15_HT_H = round(df[['Home', 'Over15_HT']].groupby('Home').mean() * 100, 2)
media_over25_HT_H = round(df[['Home', 'Over25_HT']].groupby('Home').mean() * 100, 2)

# Calculando as médias over HT para Away
media_over05_HT_A = round(df[['Away', 'Over05_HT']].groupby('Away').mean() * 100, 2)
media_over15_HT_A = round(df[['Away', 'Over15_HT']].groupby('Away').mean() * 100, 2)
media_over25_HT_A = round(df[['Away', 'Over25_HT']].groupby('Away').mean() * 100, 2)

# Concatenando as médias e salvando em um novo DataFrame, o 'df_medias'
df_medias = pd.concat([media_over05_HT_H, media_over05_HT_A, media_over15_HT_H, media_over15_HT_A, media_over25_HT_H, media_over25_HT_A], axis=1)
df_medias.columns = ['%_Over05_HT_Home','%_Over05_HT_Away','%_Over15_HT_Home','%_Over15_HT_Away','%_Over25_HT_Home','%_Over25_HT_Away']

df_medias
# Out:
#                %_Over05_HT_Home  %_Over05_HT_Away  %_Over15_HT_Home  \
# AEK                       85.71             87.50             42.86
# AZ Alkmaar               100.00             71.43             44.44
# Aberdeen                  66.67             87.50             33.33
# Ad. Demirspor             77.78             87.50             44.44
# Ajaccio                   50.00             66.67             30.00
# ...                         ...               ...               ...
# Westerlo                  90.00             70.00             40.00
# Wolfsburg                 87.50             62.50             62.50
# Wolves                    80.00             50.00             20.00
# Zaragoza                  72.73             50.00             27.27
# Zwolle                    75.00             75.00             12.50
#
#                %_Over15_HT_Away  %_Over25_HT_Home  %_Over25_HT_Away
# AEK                       50.00              0.00              37.5
# ...

# %% [markdown]
# ## Calculando as Médias de Gols, Desvio Padrão e Coeficiente de Variação

# %%
media_gols_HT_home = round(df[['Home','Goals_H_HT']].groupby('Home').mean(), 2)
media_gols_HT_away = round(df[['Away','Goals_A_HT']].groupby('Away').mean(), 2)

desvio_padrao_gols_HT_home =round( df[['Home','Goals_H_HT']].groupby('Home').std(), 2)
desvio_padrao_gols_HT_away = round(df[['Away','Goals_A_HT']].groupby('Away').std(), 2)

cv_gols_HT_home = round(desvio_padrao_gols_HT_home / media_gols_HT_home, 2)
cv_gols_HT_away = round(desvio_padrao_gols_HT_away / media_gols_HT_away, 2)

df_goals=pd.concat([media_gols_HT_home,media_gols_HT_away,desvio_padrao_gols_HT_home,desvio_padrao_gols_HT_away,cv_gols_HT_home,cv_gols_HT_away],axis=1)
df_goals.columns = ['Média_Gols_HT_Home','Média_Gols_HT_Away','DP_Gols_Home','DP_Gols_Away','CV_Gols_HT_Home','CV_Gols_HT_Away']
df_goals = df_goals[['Média_Gols_HT_Home','Média_Gols_HT_Away','CV_Gols_HT_Home','CV_Gols_HT_Away']]


df_goals
# Out:
#                Média_Gols_HT_Home  Média_Gols_HT_Away  CV_Gols_HT_Home  \
# AEK                          1.00                1.12             0.82
# AZ Alkmaar                   1.00                0.43             0.71
# Aberdeen                     0.56                0.50             1.30
# Ad. Demirspor                1.11                0.50             0.70
# Ajaccio                      0.50                0.33             1.42
# ...                           ...                 ...              ...
# Westerlo                     0.80                0.30             0.99
# Wolfsburg                    1.12                0.62             0.57
# Wolves                       0.60                0.40             0.87
# Zaragoza                     0.73                0.60             1.08
# Zwolle                       0.25                0.38             1.84
#
#                CV_Gols_HT_Away
# AEK                       0.74
# AZ Alkmaar                1.23
# ...

# %% [markdown]
# ## Juntando as Porcentagens com as Médias e CV

# %%
# Juntando as Porcentagens com as Médias e CV
df_analise = pd.concat([df_goals,df_medias],axis=1)
df_analise = df_analise.dropna()
df_analise.to_excel("analise.xlsx")

# %%
# Analisando dois times específicos
home = input("Digite o nome do Mandante: ")
away = input("Digite o nome do Visitante: ")

flt1 = df_analise[df_analise.index == home];
flt2 = df_analise[df_analise.index == away];

display(flt1, flt2)
# Out:
# Digite o nome do Mandante: Fulham
# Digite o nome do Visitante: Arsenal
#         Média_Gols_HT_Home  Média_Gols_HT_Away  CV_Gols_HT_Home  \
# Fulham                0.67                 0.4             1.67
#
#         CV_Gols_HT_Away  %_Over05_HT_Home  %_Over05_HT_Away  %_Over15_HT_Home  \
# Fulham             1.75             55.56              70.0             44.44
#
#         %_Over15_HT_Away  %_Over25_HT_Home  %_Over25_HT_Away
# Fulham              30.0             11.11              20.0
#          Média_Gols_HT_Home  Média_Gols_HT_Away  CV_Gols_HT_Home  \
# Arsenal                 0.8                0.56             0.99
#
#          CV_Gols_HT_Away  %_Over05_HT_Home  %_Over05_HT_Away  \
# Arsenal             1.57              80.0             55.56
#
#          %_Over15_HT_Home  %_Over15_HT_Away  %_Over25_HT_Home  \
# Arsenal              40.0             33.33               0.0
#
#          %_Over25_HT_Away
# Arsenal             11.11

# %%
#Div = League Division
#Date = Match Date (dd/mm/yy)
#Time = Time of match kick off
#HomeTeam = Home Team
#AwayTeam = Away Team
#FTHG and HG = Full Time Home Team Goals
#FTAG and AG = Full Time Away Team Goals
#FTR and Res = Full Time Result (H=Home Win, D=Draw, A=Away Win)
#HTHG = Half Time Home Team Goals
#HTAG = Half Time Away Team Goals
#HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
#Match Statistics (where available)
#Attendance = Crowd Attendance
#Referee = Match Referee
#HS = Home Team Shots
#AS = Away Team Shots
#HST = Home Team Shots on Target
#AST = Away Team Shots on Target
#HHW = Home Team Hit Woodwork
#AHW = Away Team Hit Woodwork
#HC = Home Team Corners
#AC = Away Team Corners
#HF = Home Team Fouls Committed
#AF = Away Team Fouls Committed
#HFKC = Home Team Free Kicks Conceded
#AFKC = Away Team Free Kicks Conceded
#HO = Home Team Offsides
#AO = Away Team Offsides
#HY = Home Team Yellow Cards
#AY = Away Team Yellow Cards
#HR = Home Team Red Cards
#AR = Away Team Red Cards
#HBP = Home Team Bookings Points (10 = yellow, 25 = red)
#ABP = Away Team Bookings Points (10 = yellow, 25 = red)

# %%
#Div = Divisão da Liga
#Date = Data da partida (dd/mm/aa)
#Time = Hora do início da partida
#HomeTeam = time da casa
#AwayTeam = Time visitante
#FTHG e HG = metas do time da casa em tempo integral
#FTAG e AG = metas da equipe visitante em tempo integral
#FTR e Res = Resultado em tempo integral (H=Vitória em casa, D=Empate, A=Vitória fora)
#HTHG = Metas do time da casa no intervalo
#HTAG = Metas da equipe fora de casa no intervalo
#HTR = Resultado no intervalo (H=Vitória em casa, D=Empate, A=Vitória fora)
#Match Statistics (quando disponível)
#Attendance = Presença da multidão
#Árbitro = Árbitro da Partida
#HS = arremessos do time da casa
#AS = chutes do time visitante
#HST = Chutes do time da casa no alvo
#AST = Chutes do time visitante no alvo
#HHW = Time da casa bateu na madeira
#AHW = Time visitante bateu na madeira
#HC = Escanteios do time da casa
#AC = Escanteios da equipe visitante
#HF = Faltas cometidas pela equipe da casa
#AF = Faltas cometidas pela equipe visitante
#HFKC = Faltas concedidas ao time da casa
#AFKC = Faltas concedidas para equipe visitante
#HO = Impedimentos do time da casa
#AO = Impedimentos do time visitante
#HY = Cartões Amarelos do Time da Casa
#AY = Cartões Amarelos do Time Visitante
#HR = Cartões vermelhos do time da casa
#AR = Cartões vermelhos do time visitante
#HBP = Pontos de reserva do time da casa (10 = amarelo, 25 = vermelho)
#ABP = Pontos de reservas da equipe visitante (10 = amarelo, 25 = vermelho)
