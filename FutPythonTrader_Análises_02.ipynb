# %% [markdown]
# <a href="https://colab.research.google.com/github/rogeriodelphi/trader_esportivo_analises/blob/main/FutPythonTrader_An%C3%A1lises_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando as Bibliotecas
import pandas as pd
import numpy as np
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
# # Importando a Base de Dados
# df = pd.read_excel('Base_de_Dados_Full_v2.xlsx')
df = pd.read_excel('/content/Base_de_Dados_Full_v2.xlsx')

# %%
# Renomeando as Colunas e Ordenando por Data os Jogos

# Selecionando as colunas que serão utilizadas
df = df[['Liga','Data','Mandante','Visitante','Odds Mandante','Odds Empate','Odds Visitante','Gols Mandante','Gols Visitante','Resultado']]
df.columns = ['League','Date','Home','Away','Odds_H','Odds_D','Odds_A','Goals_H','Goals_A','Result']
df['Date'] = df['Date'].dt.strftime('%Y/%m/%d')

# %%
# Ajustando o Índice
df.reset_index(inplace=True, drop=True)
df.index = df.index.set_names(['Nº do Jogo'])
df = df.rename(index=lambda x: x + 1)

# %%
# Visualizando o DataFrame
df
# Out:
# Warning: total number of rows (100779) exceeds max_rows (20000). Falling back to pandas display.
#              League        Date              Home             Away  Odds_H  \
# Nº do Jogo
# 1           Noruega  2012/01/04       Fredrikstad          Stabaek    2.00
# 2           Noruega  2012/01/04         Haugesund            Molde    2.35
# 3           Noruega  2012/01/04           Sogndal         Honefoss    2.04
# 4           Noruega  2012/01/04            Viking              Odd    1.79
# 5           Noruega  2012/01/04        Lillestrom        Rosenborg    3.30
# ...             ...         ...               ...              ...     ...
# 100775       México  2023/01/15            Juarez     Club Tijuana    2.32
# 100776       México  2023/01/15            Toluca     Club America    4.22
# 100777       México  2023/01/15     Santos Laguna  U.N.A.M.- Pumas    2.22
# 100778       México  2023/01/16  U.A.N.L.- Tigres          Pachuca    2.17
# 100779       México  2023/01/17         Club Leon           Necaxa    1.79
#
#             Odds_D  Odds_A  Goals_H  Goals_A Result
# Nº do Jogo
# 1             3.81    3.88        5        1      H
# 2             3.64    3.13        2        0      H
# 3             3.38    4.20        0        0      D
# 4             3.88    4.84        1        0      H
# 5             3.48    2.33        2        2      D
# ...            ...     ...      ...      ...    ...
# 100775        3.25    3.45        3        0      H
# 100776        3.96    1.85        2        2      D
# 100777        3.70    3.26        3        0      H
# 100778        3.24    3.85        4        1      H
# 100779        3.95    4.62        2        1      H
#
# [100779 rows x 10 columns]

# %%
# Criando a Coluna de Pontos Obtidos
def Pontos_H (Result):
    if Result == 'H':
        Pontos = 3
    elif Result == 'D':
        Pontos = 1
    else:
        Pontos = 0
    return Pontos

def Pontos_A (Result):
    if Result == 'A':
        Pontos = 3
    elif Result == 'D':
        Pontos = 1
    else:
        Pontos = 0
    return Pontos

df['Pontos_H'] = df.apply(lambda row: Pontos_H(row['Result']), axis=1)
df['Pontos_A'] = df.apply(lambda row: Pontos_A(row['Result']), axis=1)

# %%
df
# Out:
# Warning: total number of rows (100779) exceeds max_rows (20000). Falling back to pandas display.
#              League        Date              Home             Away  Odds_H  \
# Nº do Jogo
# 1           Noruega  2012/01/04       Fredrikstad          Stabaek    2.00
# 2           Noruega  2012/01/04         Haugesund            Molde    2.35
# 3           Noruega  2012/01/04           Sogndal         Honefoss    2.04
# 4           Noruega  2012/01/04            Viking              Odd    1.79
# 5           Noruega  2012/01/04        Lillestrom        Rosenborg    3.30
# ...             ...         ...               ...              ...     ...
# 100775       México  2023/01/15            Juarez     Club Tijuana    2.32
# 100776       México  2023/01/15            Toluca     Club America    4.22
# 100777       México  2023/01/15     Santos Laguna  U.N.A.M.- Pumas    2.22
# 100778       México  2023/01/16  U.A.N.L.- Tigres          Pachuca    2.17
# 100779       México  2023/01/17         Club Leon           Necaxa    1.79
#
#             Odds_D  Odds_A  Goals_H  Goals_A Result  Pontos_H  Pontos_A
# Nº do Jogo
# 1             3.81    3.88        5        1      H         3         0
# 2             3.64    3.13        2        0      H         3         0
# 3             3.38    4.20        0        0      D         1         1
# 4             3.88    4.84        1        0      H         3         0
# 5             3.48    2.33        2        2      D         1         1
# ...            ...     ...      ...      ...    ...       ...       ...
# 100775        3.25    3.45        3        0      H         3         0
# 100776        3.96    1.85        2        2      D         1         1
# 100777        3.70    3.26        3        0      H         3         0
# 100778        3.24    3.85        4        1      H         3         0
# 100779        3.95    4.62        2        1      H         3         0
#
# [100779 rows x 12 columns]
