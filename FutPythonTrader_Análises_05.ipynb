# %% [markdown]
# <a href="https://colab.research.google.com/github/rogeriodelphi/trader_esportivo_analises/blob/main/FutPythonTrader_An%C3%A1lises_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Estatística de Dados para Trade Esportivo - Aula 05

# %%
# Importando as Bibliotecas
import pandas as pd
import warnings

# Removendo as mensagens de warning
import warnings
warnings.filterwarnings('ignore')

# Formatando o DataFrame
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %% [markdown]
# ## Coletando as planilhas das Ligas Principais

# %%
# Inglaterra 1
ENG1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/E0.csv")
ENG1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/E0.csv")
ENG1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/E0.csv")
ENG1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/E0.csv")
ENG1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/E0.csv")
ENG1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/E0.csv")
ENG1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/E0.csv")
ENG1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/E0.csv")
ENG1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/E0.csv")
ENG1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/E0.csv")
ENG1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/E0.csv")
ENG1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/E0.csv")
ENG1 = [ENG1_01, ENG1_02, ENG1_03, ENG1_05, ENG1_06, ENG1_07, ENG1_08, ENG1_09, ENG1_10, ENG1_11, ENG1_12]
ENG1 = pd.concat(ENG1)
ENG1['Liga'] = 'Inglaterra 1'

# Inglaterra 2
ENG2_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/E1.csv")
ENG2_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/E1.csv")
ENG2_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/E1.csv")
ENG2_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/E1.csv")
ENG2_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/E1.csv")
ENG2_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/E1.csv")
ENG2_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/E1.csv")
ENG2_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/E1.csv")
ENG2_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/E1.csv")
ENG2_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/E1.csv")
ENG2_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/E1.csv")
ENG2_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/E1.csv")
ENG2 = [ENG2_01,ENG2_02,ENG2_03,ENG2_04,ENG2_05,ENG2_06,ENG2_07,ENG2_08,ENG2_09,ENG2_10, ENG2_11, ENG2_12]
ENG2 = pd.concat(ENG2)
ENG2['Liga'] = 'Inglaterra 2'

# Escócia 1
SCO1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/SC0.csv")
SCO1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/SC0.csv")
SCO1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/SC0.csv")
SCO1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/SC0.csv")
SCO1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/SC0.csv")
#SCO1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/SC0.csv")
SCO1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/SC0.csv")
SCO1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/SC0.csv")
SCO1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/SC0.csv")
SCO1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/SC0.csv")
SCO1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/SC0.csv")
SCO1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/SC0.csv")
SCO1 = [SCO1_01, SCO1_02, SCO1_03, SCO1_04, SCO1_05, SCO1_07, SCO1_08, SCO1_09, SCO1_10, SCO1_11, SCO1_12]
SCO1 = pd.concat(SCO1)
SCO1['Liga'] = 'Escócia 1'

# Alemanha 1
GER1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/D1.csv")
GER1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/D1.csv")
GER1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/D1.csv")
GER1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/D1.csv")
GER1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/D1.csv")
GER1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/D1.csv")
GER1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/D1.csv")
GER1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/D1.csv")
GER1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/D1.csv")
GER1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/D1.csv")
GER1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/D1.csv")
GER1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/D1.csv")
GER1 = [GER1_01, GER1_02, GER1_03, GER1_04, GER1_05, GER1_06, GER1_07, GER1_08, GER1_09, GER1_10, GER1_11, GER1_12]
GER1 = pd.concat(GER1)
GER1['Liga'] = 'Alemanha 1'

# Alemanha 2
GER2_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/D2.csv")
GER2_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/D2.csv")
GER2_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/D2.csv")
GER2_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/D2.csv")
GER2_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/D2.csv")
GER2_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/D2.csv")
GER2_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/D2.csv")
GER2_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/D2.csv")
GER2_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/D2.csv")
GER2_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/D2.csv")
GER2_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/D2.csv")
GER2_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/D2.csv")
GER2 = [GER2_01, GER2_02, GER2_03, GER2_04, GER2_05, GER2_06, GER2_07, GER2_08, GER2_09, GER2_10, GER2_11, GER2_12]
GER2 = pd.concat(GER2)
GER2['Liga'] = 'Alemanha 2'

# Itália 1
ITA1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/I1.csv")
ITA1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/I1.csv")
ITA1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/I1.csv")
ITA1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/I1.csv")
ITA1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/I1.csv")
ITA1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/I1.csv")
ITA1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/I1.csv")
ITA1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/I1.csv")
ITA1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/I1.csv")
ITA1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/I1.csv")
ITA1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/I1.csv")
ITA1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/I1.csv")
ITA1 = [ITA1_01, ITA1_02, ITA1_03,ITA1_04,ITA1_05,ITA1_06,ITA1_07,ITA1_08,ITA1_09,ITA1_10,ITA1_11,ITA1_12]
ITA1 = pd.concat(ITA1)
ITA1['Liga'] = 'Itália 1'

# Itália 2
ITA2_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/I2.csv")
ITA2_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/I2.csv")
ITA2_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/I2.csv")
ITA2_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/I2.csv")
ITA2_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/I2.csv")
#ITA2_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/I2.csv")
ITA2_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/I2.csv")
ITA2_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/I2.csv")
ITA2_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/I2.csv")
ITA2_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/I2.csv")
ITA2_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/I2.csv")
ITA2_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/I2.csv")
# ITA2 = [ITA2_01,ITA2_02,ITA2_03,ITA2_04,ITA2_05,ITA2_06,ITA2_07,ITA2_08,ITA2_09,ITA2_10]
ITA2 = [ITA2_01, ITA2_02, ITA2_03,ITA2_04,ITA2_05,ITA2_07,ITA2_08,ITA2_09,ITA2_10,ITA2_11,ITA2_12]
ITA2 = pd.concat(ITA2)
ITA2['Liga'] = 'Itália 2'

# Espanha 1
SPA1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/SP1.csv")
SPA1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/SP1.csv")
SPA1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/SP1.csv")
SPA1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/SP1.csv")
SPA1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/SP1.csv")
SPA1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/SP1.csv")
SPA1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/SP1.csv")
SPA1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/SP1.csv")
SPA1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/SP1.csv")
SPA1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/SP1.csv")
SPA1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/SP1.csv")
SPA1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/SP1.csv")
SPA1 = [SPA1_01, SPA1_02, SPA1_03,SPA1_04,SPA1_05,SPA1_06,SPA1_07,SPA1_08,SPA1_09,SPA1_10,SPA1_11,SPA1_12]
SPA1 = pd.concat(SPA1)
SPA1['Liga'] = 'Espanha 1'

# Espanha 2
SPA2_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/SP2.csv")
SPA2_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/SP2.csv")
SPA2_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/SP2.csv")
SPA2_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/SP2.csv")
SPA2_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/SP2.csv")
SPA2_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/SP2.csv")
SPA2_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/SP2.csv")
SPA2_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/SP2.csv")
SPA2_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/SP2.csv")
SPA2_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/SP2.csv")
SPA2_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/SP2.csv")
SPA2_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/SP2.csv")
SPA2 = [SPA2_01, SPA2_02, SPA2_03,SPA2_04,SPA2_05,SPA2_06,SPA2_07,SPA2_08,SPA2_09,SPA2_10,SPA2_11,SPA2_12]
SPA2 = pd.concat(SPA2)
SPA2['Liga'] = 'Espanha 2'

# França 1
FRA1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/F1.csv")
FRA1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/F1.csv")
FRA1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/F1.csv")
FRA1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/F1.csv")
FRA1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/F1.csv")
FRA1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/F1.csv")
FRA1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/F1.csv")
FRA1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/F1.csv")
FRA1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/F1.csv")
FRA1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/F1.csv")
FRA1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/F1.csv")
FRA1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/F1.csv")
FRA1 = [FRA1_01, FRA1_02, FRA1_03,FRA1_04,FRA1_05,FRA1_06,FRA1_07,FRA1_08,FRA1_09,FRA1_10,FRA1_11,FRA1_12]
FRA1 = pd.concat(FRA1)
FRA1['Liga'] = 'França 1'

# França 2
FRA2_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/F2.csv")
FRA2_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/F2.csv")
FRA2_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/F2.csv")
FRA2_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/F2.csv")
FRA2_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/F2.csv")
FRA2_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/F2.csv")
FRA2_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/F2.csv")
FRA2_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/F2.csv")
FRA2_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/F2.csv")
FRA2_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/F2.csv")
FRA2_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/F2.csv")
FRA2_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/F2.csv")
FRA2 = [FRA2_01, FRA2_02, FRA2_03,FRA2_04,FRA2_05,FRA2_06,FRA2_07,FRA2_08,FRA2_09,FRA2_10,FRA2_11,FRA2_12]
FRA2 = pd.concat(FRA2)
FRA2['Liga'] = 'França 2'

# Holanda 1
NET1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/N1.csv")
NET1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/N1.csv")
NET1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/N1.csv")
NET1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/N1.csv")
NET1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/N1.csv")
NET1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/N1.csv")
NET1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/N1.csv")
NET1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/N1.csv")
NET1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/N1.csv")
NET1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/N1.csv")
NET1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/N1.csv")
NET1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/N1.csv")
NET1 = [NET1_01, NET1_02, NET1_03,NET1_04,NET1_05,NET1_06,NET1_07,NET1_08,NET1_09,NET1_10,NET1_11,NET1_12]
NET1 = pd.concat(NET1)
NET1['Liga'] = 'Holanda 1'

# Bélgica 1
BEL1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/B1.csv")
BEL1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/B1.csv")
BEL1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/B1.csv")
BEL1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/B1.csv")
BEL1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/B1.csv")
BEL1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/B1.csv")
BEL1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/B1.csv")
BEL1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/B1.csv")
BEL1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/B1.csv")
BEL1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/B1.csv")
BEL1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/B1.csv")
BEL1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/B1.csv")
BEL1 = [BEL1_01, BEL1_02, BEL1_03,BEL1_04,BEL1_05,BEL1_06,BEL1_07,BEL1_08,BEL1_09,BEL1_10,BEL1_11,BEL1_12]
BEL1 = pd.concat(BEL1)
BEL1['Liga'] = 'Bélgica 1'

# Portugal 1
POR1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/P1.csv")
POR1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/P1.csv")
POR1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/P1.csv")
POR1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/P1.csv")
POR1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/P1.csv")
POR1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/P1.csv")
POR1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/P1.csv")
POR1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/P1.csv")
POR1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/P1.csv")
POR1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/P1.csv")
POR1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/P1.csv")
POR1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/P1.csv")
POR1 = [POR1_01, POR1_02, POR1_03, POR1_04, POR1_05, POR1_06, POR1_07, POR1_08, POR1_09, POR1_10, POR1_11, POR1_12]
POR1 = pd.concat(POR1)
POR1['Liga'] = 'Portugal 1'

# Turquia 1
TUR1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/T1.csv")
TUR1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/T1.csv")
TUR1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/T1.csv")
TUR1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/T1.csv")
TUR1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/T1.csv")
TUR1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/T1.csv")
TUR1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/T1.csv")
TUR1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/T1.csv")
TUR1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/T1.csv")
TUR1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/T1.csv")
TUR1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/T1.csv")
TUR1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/T1.csv")
TUR1 = [TUR1_01, TUR1_02, TUR1_03, TUR1_04, TUR1_05, TUR1_06, TUR1_07, TUR1_08, TUR1_09, TUR1_10, TUR1_11, TUR1_12]
TUR1 = pd.concat(TUR1)
TUR1['Liga'] = 'Turquia 1'

# Grécia 1
GRE1_01 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/G1.csv")
GRE1_02 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/G1.csv")
GRE1_03 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/G1.csv")
GRE1_04 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/G1.csv")
GRE1_05 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/G1.csv")
GRE1_06 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/G1.csv")
GRE1_07 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/G1.csv")
GRE1_08 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/G1.csv")
GRE1_09 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/G1.csv")
GRE1_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/G1.csv")
GRE1_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1314/G1.csv")
GRE1_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1213/G1.csv")
GRE1 = [GRE1_01, GRE1_02, GRE1_03, GRE1_04, GRE1_05, GRE1_06, GRE1_07, GRE1_08, GRE1_09, GRE1_10, GRE1_11, GRE1_12]
GRE1 = pd.concat(GRE1)
GRE1['Liga'] = 'Grécia 1'

# %% [markdown]
# ## Concatenando as Planilhas

# %%
df = df[['Liga','Date','HomeTeam','AwayTeam','HTHG','HTAG','HTR','FTHG','FTAG','FTR','B365H','B365D','B365A']]
df.columns = ['League','Date','Home','Away','Goals_H_HT','Goals_A_HT','Result_HT','Goals_H_FT','Goals_A_FT','Result_FT','Odd_H','Odds_D','Odds_A']

# %%
# Ajustando o índice
df.reset_index(inplace=True, drop=True)
df.index = df.index.set_names(['Nº do Jogo'])
df = df.rename(index=lambda x: x + 1)

# %%
# Visualizando o Resultado Final
df.head(10)
# Out:
#                   League        Date              Home            Away  \
# Nº do Jogo
# 1           Inglaterra 1  11/08/2023           Burnley        Man City
# 2           Inglaterra 1  12/08/2023           Arsenal   Nott'm Forest
# 3           Inglaterra 1  12/08/2023       Bournemouth        West Ham
# 4           Inglaterra 1  12/08/2023          Brighton           Luton
# 5           Inglaterra 1  12/08/2023           Everton          Fulham
# 6           Inglaterra 1  12/08/2023  Sheffield United  Crystal Palace
# 7           Inglaterra 1  12/08/2023         Newcastle     Aston Villa
# 8           Inglaterra 1  13/08/2023         Brentford       Tottenham
# 9           Inglaterra 1  13/08/2023           Chelsea       Liverpool
# 10          Inglaterra 1  14/08/2023        Man United          Wolves
#
#             Goals_H_HT  Goals_A_HT Result_HT  Goals_H_FT  Goals_A_FT  \
# Nº do Jogo
# 1                  0.0         2.0         A         0.0         3.0
# ...

# %% [markdown]
# ## Informações do DataFrame

# %%
df.info()

# %% [markdown]
# # Dropando as linhas com NAN

# %%
df = df.dropna()

# %% [markdown]
# ## Visualizando o Resultado Final

# %%
df.info

# %%
df.head()
# Out:
#                   League        Date         Home           Away  Goals_H_HT  \
# Nº do Jogo
# 1           Inglaterra 1  11/08/2023      Burnley       Man City         0.0
# 2           Inglaterra 1  12/08/2023      Arsenal  Nott'm Forest         2.0
# 3           Inglaterra 1  12/08/2023  Bournemouth       West Ham         0.0
# 4           Inglaterra 1  12/08/2023     Brighton          Luton         1.0
# 5           Inglaterra 1  12/08/2023      Everton         Fulham         0.0
#
#             Goals_A_HT Result_HT  Goals_H_FT  Goals_A_FT Result_FT  Odd_H  \
# Nº do Jogo
# 1                  2.0         A         0.0         3.0         A   8.00
# 2                  0.0         H         2.0         1.0         H   1.18
# 3                  0.0         D         1.0         1.0         D   2.70
# 4                  0.0         H         4.0         1.0         H   1.33
# 5                  0.0         D         0.0         1.0         A   2.20
#
# ...

# %% [markdown]
# ## Exportando arquivo final para o Excel

# %%
df.to_excel("Base_de_Dados_Full.xlsx", index=False)

# %% [markdown]
# ## Calculando as porcentagens de Over 0.5 HT, 1.5 HT e 2.5 HT

# %%
# Criando o campo coluna 'Total_Goals_HT'no DataFrame df
df['Total_Goals_HT'] = df.apply(lambda row: (row['Goals_H_HT'] + row['Goals_A_HT']), axis=1)

# Calculando as porcentagens de Over 0.5 HT, 1.5 HT e 2.5 HT
df['Over05_HT'] = df.apply(lambda row: 1 if (row['Total_Goals_HT'] >= 1) else 0, axis=1)
df['Over15_HT'] = df.apply(lambda row: 1 if (row['Total_Goals_HT'] > 1) else 0, axis=1)
df['Over25_HT'] = df.apply(lambda row: 1 if (row['Total_Goals_HT'] > 2) else 0, axis=1)

# Calculando as médias over HT para Home
media_over05_HT_H = round(df[['Home', 'Over05_HT']].groupby('Home').mean() * 100, 2)
media_over15_HT_H = round(df[['Home', 'Over15_HT']].groupby('Home').mean() * 100, 2)
media_over25_HT_H = round(df[['Home', 'Over25_HT']].groupby('Home').mean() * 100, 2)

# Calculando as médias over HT para Away
media_over05_HT_A = round(df[['Away', 'Over05_HT']].groupby('Away').mean() * 100, 2)
media_over15_HT_A = round(df[['Away', 'Over15_HT']].groupby('Away').mean() * 100, 2)
media_over25_HT_A = round(df[['Away', 'Over25_HT']].groupby('Away').mean() * 100, 2)

# Concatenando as médias e salvando em um novo DataFrame, o 'df_medias'
df_medias = pd.concat([media_over05_HT_H, media_over05_HT_A, media_over15_HT_H, media_over15_HT_A, media_over25_HT_H, media_over25_HT_A], axis=1)
df_medias.columns = ['%_Over05_HT_Home','%_Over05_HT_Away','%_Over15_HT_Home','%_Over15_HT_Away','%_Over25_HT_Home','%_Over25_HT_Away']

df_medias
# Out:
#                   %_Over05_HT_Home  %_Over05_HT_Away  %_Over15_HT_Home  \
# AEK                          69.74             65.33             31.58
# AZ Alkmaar                   76.96             78.31             46.60
# Aalen                        62.75             58.82             17.65
# Aberdeen                     68.91             67.69             29.53
# Academica                    70.31             64.06             35.94
# ...                            ...               ...               ...
# Xerez                        66.67             71.43             23.81
# Yeni Malatyaspor             71.11             68.54             35.56
# Yeovil                       47.83             65.22             21.74
# Zaragoza                     66.11             63.60             25.94
# Zwolle                       76.30             74.29             38.15
#
#                   %_Over15_HT_Away  %_Over25_HT_Home  %_Over25_HT_Away
# ...

# %% [markdown]
# ## Calculando as Médias de Gols, Desvio Padrão e Coeficiente de Variação

# %%
media_gols_HT_home = round(df[['Home','Goals_H_HT']].groupby('Home').mean(), 2)
media_gols_HT_away = round(df[['Away','Goals_A_HT']].groupby('Away').mean(), 2)

desvio_padrao_gols_HT_home =round( df[['Home','Goals_H_HT']].groupby('Home').std(), 2)
desvio_padrao_gols_HT_away = round(df[['Away','Goals_A_HT']].groupby('Away').std(), 2)

cv_gols_HT_home = round(desvio_padrao_gols_HT_home / media_gols_HT_home, 2)
cv_gols_HT_away = round(desvio_padrao_gols_HT_away / media_gols_HT_away, 2)

df_goals=pd.concat([media_gols_HT_home,media_gols_HT_away,desvio_padrao_gols_HT_home,desvio_padrao_gols_HT_away,cv_gols_HT_home,cv_gols_HT_away],axis=1)
df_goals.columns = ['Média_Gols_HT_Home','Média_Gols_HT_Away','DP_Gols_Home','DP_Gols_Away','CV_Gols_HT_Home','CV_Gols_HT_Away']
df_goals = df_goals[['Média_Gols_HT_Home','Média_Gols_HT_Away','CV_Gols_HT_Home','CV_Gols_HT_Away']]


df_goals
# Out:
#                   Média_Gols_HT_Home  Média_Gols_HT_Away  CV_Gols_HT_Home  \
# AEK                             0.83                0.65             1.08
# AZ Alkmaar                      0.97                0.80             1.06
# Aalen                           0.45                0.27             1.29
# Aberdeen                        0.70                0.60             1.21
# Academica                       0.55                0.25             1.33
# ...                              ...                 ...              ...
# Xerez                           0.33                0.48             1.45
# Yeni Malatyaspor                0.58                0.35             1.26
# Yeovil                          0.43                0.65             1.84
# Zaragoza                        0.59                0.52             1.27
# Zwolle                          0.59                0.46             1.20
#
#                   CV_Gols_HT_Away
# AEK                          1.29
# ...

# %% [markdown]
# ## Juntando as Porcentagens com as Médias e CV

# %%
# Juntando as Porcentagens com as Médias e CV
df_analise = pd.concat([df_goals,df_medias],axis=1)
df_analise = df_analise.dropna()
df_analise.to_excel("analise.xlsx")

# %%
# Analisando dois times específicos
home = input("Digite o nome do Mandante: ")
away = input("Digite o nome do Visitante: ")

flt1 = df_analise[df_analise.index == home];
flt2 = df_analise[df_analise.index == away];

display(flt1, flt2)
# Out:
# Digite o nome do Mandante: Chelsea
# Digite o nome do Visitante: Arsenal
#          Média_Gols_HT_Home  Média_Gols_HT_Away  CV_Gols_HT_Home  \
# Chelsea                 0.9                0.76             0.94
#
#          CV_Gols_HT_Away  %_Over05_HT_Home  %_Over05_HT_Away  \
# Chelsea             1.13              69.0              71.5
#
#          %_Over15_HT_Home  %_Over15_HT_Away  %_Over25_HT_Home  \
# Chelsea              40.5              37.5              13.0
#
#          %_Over25_HT_Away
# Chelsea              14.5
#          Média_Gols_HT_Home  Média_Gols_HT_Away  CV_Gols_HT_Home  \
# Arsenal                0.92                 0.7             1.05
#
#          CV_Gols_HT_Away  %_Over05_HT_Home  %_Over05_HT_Away  \
# Arsenal             1.17              73.5             74.37
#
#          %_Over15_HT_Home  %_Over15_HT_Away  %_Over25_HT_Home  \
# Arsenal              41.0              39.7              16.0
#
#          %_Over25_HT_Away
# Arsenal             14.57
